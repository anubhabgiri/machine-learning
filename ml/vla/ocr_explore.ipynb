# %%
import pytesseract
text = pytesseract.image_to_string("linkedin_feed_sample.png")

print(text)
# Out:
# 1,109) - anubhabgiri@:
#
# ca
#
# linkedin.com,
#
# Anubhab Giri
#
# Profile viewers 67
#
# Post impressions 4
#
# WW Get 50% off Premium
#
# WA Saved items
#
# Groups
#
# Events +
#
# Discover more
#
# if Feed | Linkedin
#
# id = 9 a
#
# Home — MyNetwork Jobs. Messaging Notifications
#
# Start a post
#
# @ Video &) Photo
#
# Write article
#
# Sort by: Top +
#
# x
#
# @ secre
#
# ie) Abhishek Sinha
#
# Studio Ghibli meets Satyajit Ray! My humble tribute to the father of Indian Cinema. |
# know this is the trend and social media is saturated with Ghibli clones, But when the
# visuals are pulsating to the beats of Ray's own music, this one is surely ..more
#
# + Follow
#
# 8 comments -
#
# Like © Comment Repost J Send
#
# Innovate, grow, and make an impact with cutting-edge technology. Join a team
# that's shaping the future of Al, security, and cloud.
#
# 6 i
#
# Mew For Business ¥ 50% Off
#
# Trending Now
#
# curated by Linkedin News
#
# White House sets 25% auto tariffs
#
# ...

# %% [markdown]
# this is clearly very unstructured and not fit for Computer action model
